# %%
# %matplotlib inline

#import sys
import numpy as np
#np.set_printoptions(threshold=sys.maxsize)
import matplotlib.pyplot as plt
import matplotlib.colors as cm
import pynbody
from michaels_functions import center_and_r_vir, remove_bulk_velocity
from matplotlib.colors import LogNorm
from matplotlib.pyplot import figure

# %%
n_H_arr = pynbody.array.SimArray(np.load('outputs/sub_grid_evolution/n_H.npy'), "cm**-3")
n_H2_arr = pynbody.array.SimArray(np.load('outputs/sub_grid_evolution/n_H2.npy'), "cm**-3")
X_H2_arr = pynbody.array.SimArray(np.load('outputs/sub_grid_evolution/X_H2.npy'), "1")
n_LW_arr = np.load('outputs/sub_grid_evolution/n_LW.npy')
n_LW_ss_arr = np.load('outputs/sub_grid_evolution/n_LW_ss.npy')
X_H2_ss_arr = pynbody.array.SimArray(np.load('outputs/sub_grid_evolution/X_H2_ss.npy'), "1")
n_H2_ss_arr = pynbody.array.SimArray(np.load('outputs/sub_grid_evolution/n_H2_ss.npy'), "cm**-3")
X_CO_arr = pynbody.array.SimArray(np.load('outputs/sub_grid_evolution/X_CO.npy'), "1")
n_CO_arr = pynbody.array.SimArray(np.load('outputs/sub_grid_evolution/n_CO.npy'), "cm**-3")
pdf_arr = np.load('outputs/sub_grid_evolution/pdf.npy')
pdf_prime_arr = np.load('outputs/sub_grid_evolution/pdf_prime.npy')
lambda_jeans_arr = pynbody.array.SimArray(np.load('outputs/sub_grid_evolution/lambda_jeans.npy'), "cm")

# %%
plt.rc('figure', titlesize=18)
plt.rc('axes', titlesize=18)     # fontsize of the axes title
plt.rc('axes', labelsize=18)    # fontsize of the x and y labels

# %%
plt.figure(figsize=(9,5))
ax = plt.gca()
plt.plot(np.log10(n_H_arr), pdf_prime_arr, c="b", lw=3)
# ax.set_ylim([-6,1])
# ax.set_xlim([-1, 3])
plt.xlabel('$log(n_{H}/n_{H, mean})$')
plt.ylabel('$PDF$')
plt.grid(b=True, which='both', axis='both')
plt.title("$log(n_{H}/n_{H, mean})$ vs $PDF$")
plt.savefig('outputs/sub_grid_evolution/log(n_H)vsPDF.png', 
            dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(9,5))
ax = plt.gca()
plt.plot(np.log10(n_H_arr), np.log10(pdf_prime_arr), c="b", lw=3)
# ax.set_ylim([-6,1])
# ax.set_xlim([-1, 3])
plt.xlabel('$log(n_{H}/n_{H, mean})$')
plt.ylabel('$log(PDF)$')
plt.grid(b=True, which='both', axis='both')
plt.title("$log(n_{H}/n_{H, mean})$ vs $log(PDF)$")
plt.savefig('outputs/sub_grid_evolution/log(n_H)vslog(PDF).png', 
            dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(9,5))
ax = plt.gca()
plt.plot(np.log10(n_H_arr), lambda_jeans_arr, c="b", lw=3)
# ax.set_ylim([-6,1])
# ax.set_xlim([-1, 3])
plt.xlabel('$log(n_{H}/n_{H, mean})$')
plt.ylabel('$\lambda_{Jeans} \ (cm)$')
plt.grid(b=True, which='both', axis='both')
plt.title("$log(n_{H}/n_{H, mean})$ vs $\lambda_{Jeans} \ (cm)$")
plt.savefig('outputs/sub_grid_evolution/log(n_H)vslambda_jeans.png', 
            dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(9,5))
ax = plt.gca()
plt.plot(np.log10(n_H_arr), np.log10(lambda_jeans_arr), c="b", lw=3)
# ax.set_ylim([-6,1])
# ax.set_xlim([-1, 3])
plt.xlabel('$log(n_{H}/n_{H, mean})$')
plt.ylabel('$log(\lambda_{Jeans}) \ (cm)$')
plt.grid(b=True, which='both', axis='both')
plt.title("$log(n_{H}/n_{H, mean})$ vs $log(\lambda_{Jeans}) \ (cm)$")
plt.savefig('outputs/sub_grid_evolution/log(n_H)vslambda_jeans.png', 
            dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(9,5))
ax = plt.gca()
plt.plot(np.log10(n_H_arr), X_H2_arr, c="b", lw=3)
# ax.set_ylim([-6,1])
# ax.set_xlim([-1, 3])
plt.xlabel('$log(n_{H}/n_{H, mean})$')
plt.ylabel('$X_{H2}$')
plt.grid(b=True, which='both', axis='both')
plt.title("$log(n_{H}/n_{H, mean})$ vs $X_{H2}$")
plt.savefig('outputs/sub_grid_evolution/log(n_H)vsX_H2.png', 
            dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(9,5))
ax = plt.gca()
plt.plot(np.log10(n_H_arr), X_H2_ss_arr, c="b", lw=3)
# ax.set_ylim([-6,1])
# ax.set_xlim([-1, 3])
plt.xlabel('$log(n_{H}/n_{H, mean})$')
plt.ylabel('$X_{H2, SS}$')
plt.grid(b=True, which='both', axis='both')
plt.title("$log(n_{H}/n_{H, mean})$ vs $X_{H2, SS}$")
plt.savefig('outputs/sub_grid_evolution/log(n_H)vsX_H2_ss.png', 
            dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(9,5))
ax = plt.gca()
plt.plot(np.log10(n_H_arr), X_CO_arr, c="b", lw=3)
# ax.set_ylim([-6,1])
# ax.set_xlim([-1, 3])
plt.xlabel('$log(n_{H}/n_{H, mean})$')
plt.ylabel('$X_{CO}$')
plt.grid(b=True, which='both', axis='both')
plt.title("$log(n_{H}/n_{H, mean})$ vs $X_{CO}$")
plt.savefig('outputs/sub_grid_evolution/log(n_H)vsX_CO.png', 
            dpi=300, bbox_inches='tight')
plt.show()
